# %%
import json

input = '''
[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Chuck"
  } 
]'''

info = json.loads(input)
print 'User count:', len(info)

for item in info:
    print 'Name', item['name']
    print 'Id', item['id']
    print 'Attribute', item['x']
# Out:
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Chuck
# Id 009
# Attribute 7

# %%
import urllib
import xml.etree.ElementTree as ET

serviceurl = 'http://maps.googleapis.com/maps/api/geocode/xml?'

while True:
    address = raw_input('Enter location: ')
    if len(address) < 1 : break

    url = serviceurl + urllib.urlencode({'sensor':'false', 'address': address})
    print 'Retrieving', url
    uh = urllib.urlopen(url)
    data = uh.read()
    print 'Retrieved',len(data),'characters'
    print data
    tree = ET.fromstring(data)
    print tree

    results = tree.findall('result')
    lat = results[0].find('geometry').find('location').find('lat').text
    lng = results[0].find('geometry').find('location').find('lng').text
    location = results[0].find('formatted_address').text

    print 'lat',lat,'lng',lng
    print location
# Out:
# Enter location: http://python-data.dr-chuck.net/comments_42.json
# Retrieving http://maps.googleapis.com/maps/api/geocode/xml?sensor=false&address=http%3A%2F%2Fpython-data.dr-chuck.net%2Fcomments_42.json
# Retrieved 107 characters
# <?xml version="1.0" encoding="UTF-8"?>
# <GeocodeResponse>
#  <status>ZERO_RESULTS</status>
# </GeocodeResponse>
#
# <Element 'GeocodeResponse' at 0x111376950>

# %%
import urllib
import json


while True:
    address = raw_input('Enter location: ')
    if len(address) < 1 : break 
    print 'Retrieving', address
    
    uh = urllib.urlopen(address)
    data = uh.read()
    print 'Retrieved',len(data),'characters'
    print data

    data_parsed = json.loads(data)
    print 'User count:', len(data)

    total = 0
    for item in data_parsed["comments"]:
        total += int(item["count"])

    print 'Sum: ', total
# Out:
# Enter location: http://python-data.dr-chuck.net/comments_42.json
# Retrieving http://python-data.dr-chuck.net/comments_42.json
# Retrieved 2711 characters
# {
#   "note":"This file contains the sample data for testing",
#   "comments":[
#     {
#       "name":"Romina",
#       "count":97
#     },
#     {
#       "name":"Laurie",
#       "count":97
#     },
#     {
#       "name":"Bayli",
#       "count":90
#     },
#     {
#       "name":"Siyona",
#       "count":90
#     },
#     {
#       "name":"Taisha",
#       "count":88
#     },
#     {
#       "name":"Alanda",
#       "count":87
#     },
#     {
#       "name":"Ameelia",
#       "count":87
#     },
#     {
#       "name":"Prasheeta",
#       "count":80
#     },
#     {
#       "name":"Asif",
#       "count":79
#     },
#     {
#       "name":"Risa",
#       "count":79
#     },
#     {
#       "name":"Zi",
#       "count":78
#     },
#     {
#       "name":"Danyil",
#       "count":76
#     },
#     {
#       "name":"Ediomi",
#       "count":76
#     },
#     {
#       "name":"Barry",
#       "count":72
#     },
#     {
#       "name":"Lance",
#       "count":72
#     },
#     {
#       "name":"Hattie",
#       "count":66
#     },
#     {
#       "name":"Mathu",
#       "count":66
#     },
#     {
#       "name":"Bowie",
#       "count":65
#     },
#     {
#       "name":"Samara",
#       "count":65
#     },
#     {
#       "name":"Uchenna",
#       "count":64
#     },
#     {
#       "name":"Shauni",
#       "count":61
#     },
#     {
#       "name":"Georgia",
#       "count":61
#     },
#     {
#       "name":"Rivan",
#       "count":59
#     },
#     {
#       "name":"Kenan",
#       "count":58
#     },
#     {
#       "name":"Hassan",
#       "count":57
#     },
#     {
#       "name":"Isma",
#       "count":57
#     },
#     {
#       "name":"Samanthalee",
#       "count":54
#     },
#     {
#       "name":"Alexa",
#       "count":51
#     },
#     {
#       "name":"Caine",
#       "count":49
#     },
#     {
#       "name":"Grady",
#       "count":47
#     },
#     {
#       "name":"Anne",
#       "count":40
#     },
#     {
#       "name":"Rihan",
#       "count":38
#     },
#     {
#       "name":"Alexei",
#       "count":37
#     },
#     {
#       "name":"Indie",
#       "count":36
#     },
#     {
#       "name":"Rhuairidh",
#       "count":36
#     },
#     {
#       "name":"Annoushka",
#       "count":32
#     },
#     {
#       "name":"Kenzi",
#       "count":25
#     },
#     {
#       "name":"Shahd",
#       "count":24
#     },
#     {
#       "name":"Irvine",
#       "count":22
#     },
#     {
#       "name":"Carys",
#       "count":21
#     },
#     {
#       "name":"Skye",
#       "count":19
#     },
#     {
#       "name":"Atiya",
#       "count":18
#     },
#     {
#       "name":"Rohan",
#       "count":18
#     },
#     {
#       "name":"Nuala",
#       "count":14
#     },
#     {
#       "name":"Maram",
#       "count":12
#     },
#     {
#       "name":"Carlo",
#       "count":12
#     },
#     {
#       "name":"Japleen",
#       "count":9
#     },
#     {
#       "name":"Breeanna",
#       "count":7
#     },
#     {
#       "name":"Zaaine",
#       "count":3
#     },
#     {
#       "name":"Inika",
#       "count":2
#     }
#   ]
# }
# User count: 2711
# Sum:  2553
# Enter location: http://python-data.dr-chuck.net/comments_306521.json
# Retrieving http://python-data.dr-chuck.net/comments_306521.json
# Retrieved 2711 characters
# {
#   "note":"This file contains the actual data for your assignment",
#   "comments":[
#     {
#       "name":"Maxim",
#       "count":98
#     },
#     {
#       "name":"Lucas",
#       "count":91
#     },
#     {
#       "name":"Kelvin",
#       "count":86
#     },
#     {
#       "name":"Ross",
#       "count":85
#     },
#     {
#       "name":"Finnean",
#       "count":85
#     },
#     {
#       "name":"Malaika",
#       "count":84
#     },
#     {
#       "name":"Eva",
#       "count":83
#     },
#     {
#       "name":"Lylah",
#       "count":81
#     },
#     {
#       "name":"Nur",
#       "count":79
#     },
#     {
#       "name":"Aodhan",
#       "count":78
#     },
#     {
#       "name":"Keiryn",
#       "count":78
#     },
#     {
#       "name":"Khaia",
#       "count":74
#     },
#     {
#       "name":"Saad",
#       "count":74
#     },
#     {
#       "name":"Edwin",
#       "count":72
#     },
#     {
#       "name":"Mairin",
#       "count":71
#     },
#     {
#       "name":"Zaaine",
#       "count":71
#     },
#     {
#       "name":"Kassidy",
#       "count":69
#     },
#     {
#       "name":"Abhisumant",
#       "count":68
#     },
#     {
#       "name":"Chaitanya",
#       "count":68
#     },
#     {
#       "name":"Areeb",
#       "count":63
#     },
#     {
#       "name":"Davie",
#       "count":62
#     },
#     {
#       "name":"Cully",
#       "count":60
#     },
#     {
#       "name":"Abraham",
#       "count":56
#     },
#     {
#       "name":"Temitayo",
#       "count":55
#     },
#     {
#       "name":"Ruben",
#       "count":52
#     },
#     {
#       "name":"Gus",
#       "count":52
#     },
#     {
#       "name":"Starr",
#       "count":49
#     },
#     {
#       "name":"Miao",
#       "count":48
#     },
#     {
#       "name":"Abar",
#       "count":48
#     },
#     {
#       "name":"Jaida",
#       "count":47
#     },
#     {
#       "name":"Mikey",
#       "count":46
#     },
#     {
#       "name":"Ayub",
#       "count":44
#     },
#     {
#       "name":"Erik",
#       "count":44
#     },
#     {
#       "name":"Caite",
#       "count":42
#     },
#     {
#       "name":"Shahmir",
#       "count":41
#     },
#     {
#       "name":"Mirabelle",
#       "count":38
#     },
#     {
#       "name":"Kofi",
#       "count":35
#     },
#     {
#       "name":"Avah",
#       "count":34
#     },
#     {
#       "name":"Nathanael",
#       "count":33
#     },
#     {
#       "name":"Robby",
#       "count":32
#     },
#     {
#       "name":"Derren",
#       "count":31
#     },
#     {
#       "name":"Fearn",
#       "count":28
#     },
#     {
#       "name":"Nyah",
#       "count":26
#     },
#     {
#       "name":"Skye",
#       "count":25
#     },
#     {
#       "name":"Rivan",
#       "count":19
#     },
#     {
#       "name":"Hishaam",
#       "count":17
#     },
#     {
#       "name":"Naz",
#       "count":15
#     },
#     {
#       "name":"Aiadan",
#       "count":11
#     },
#     {
#       "name":"Rebekah",
#       "count":3
#     },
#     {
#       "name":"Soukina",
#       "count":1
#     }
#   ]
# }
# User count: 2711
# Sum:  2652
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-949eea0fb8a6> in <module>()
#       4
#       5 while True:
# ----> 6     address = raw_input('Enter location: ')
#       7     if len(address) < 1 : break
#       8     print 'Retrieving', address
#
# /Users/jingqin/venv2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     692             self._parent_ident,
#     693             self._parent_header,
# --> 694             password=False,
#     695         )
#     696
#
# /Users/jingqin/venv2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     722             except KeyboardInterrupt:
#     723                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 724                 raise KeyboardInterrupt
#     725             else:
#     726                 break
#
# KeyboardInterrupt:

# %%
import urllib
import json

# serviceurl = 'http://maps.googleapis.com/maps/api/geocode/json?'
serviceurl = 'http://python-data.dr-chuck.net/geojson?'

while True:University of Evora
    address = raw_input('Enter location: ')
    if len(address) < 1 : break

    url = serviceurl + urllib.urlencode({'sensor':'false', 'address': address})
    print 'Retrieving', url
    uh = urllib.urlopen(url)
    data = uh.read()
    print 'Retrieved',len(data),'characters'

    try: js = json.loads(str(data))
    except: js = None
    if 'status' not in js or js['status'] != 'OK':
        print '==== Failure To Retrieve ===='
       # print data
        continue

    print json.dumps(js, indent=4)

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    print 'lat',lat,'lng',lng
    location = js['results'][0]['formatted_address']
    print location
    id = js["results"][0]["place_id"]
    print id
# Out:
# Enter location: South Federal University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=South+Federal+University+
# Retrieved 10092 characters
# ==== Failure To Retrieve ====
# Enter location: University of Evora
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Evora
# Retrieved 1795 characters
# {
#     "status": "OK",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 51.8887362,
#                     "lng": -8.4947274
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 51.89008518029149,
#                         "lng": -8.493378419708499
#                     },
#                     "southwest": {
#                         "lat": 51.88738721970849,
#                         "lng": -8.496076380291504
#                     }
#                 },
#                 "location_type": "ROOFTOP"
#             },
#             "formatted_address": "Evora, Magazine Rd, Coolgarten Park, Cork, Ireland",
#             "place_id": "ChIJw3_NFyaQREgRdJjDhr9duqY",
#             "address_components": [
#                 {
#                     "long_name": "Evora",
#                     "types": [
#                         "premise"
#                     ],
#                     "short_name": "Evora"
#                 },
#                 {
#                     "long_name": "Magazine Road",
#                     "types": [
#                         "route"
#                     ],
#                     "short_name": "Magazine Rd"
#                 },
#                 {
#                     "long_name": "Cork",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Cork"
#                 },
#                 {
#                     "long_name": "Cork City",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Cork City"
#                 },
#                 {
#                     "long_name": "Cork",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "Cork"
#                 },
#                 {
#                     "long_name": "Ireland",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "IE"
#                 }
#             ],
#             "partial_match": true,
#             "types": [
#                 "premise"
#             ]
#         }
#     ]
# }
# lat 51.8887362 lng -8.4947274
# Evora, Magazine Rd, Coolgarten Park, Cork, Ireland
# ChIJw3_NFyaQREgRdJjDhr9duqY
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-de405a906ca4> in <module>()
#       6
#       7 while True:
# ----> 8     address = raw_input('Enter location: ')
#       9     if len(address) < 1 : break
#      10
#
# /Users/jingqin/venv2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     692             self._parent_ident,
#     693             self._parent_header,
# --> 694             password=False,
#     695         )
#     696
#
# /Users/jingqin/venv2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     722             except KeyboardInterrupt:
#     723                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 724                 raise KeyboardInterrupt
#     725             else:
#     726                 break
#
# KeyboardInterrupt:
