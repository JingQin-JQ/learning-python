# %%
a = 1

# %%
print a
# Out:
# 1

# %% [markdown]
# **xiaojj**
# xiaojj

# %% [markdown]
# # test 1

# %% [markdown]
# # problem 3

# %% [markdown]
# This is problem *asdf*

# %%
def shut_down(s):
    s=input(" Do you want to shut down?")
    if s=="yes"
       return "Shutting down"
    elif s=="no"
       return "Shoutdown aborted"
    else s!="yes" or s!="no"
       return "Sorry!"
# Out:
#   File "<ipython-input-3-5b367ebff4b9>", line 3
#     if s=="yes"
#                ^
# SyntaxError: invalid syntax

# %%
for i in range(19):
    print "hello world"
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world

# %%
range(1)
# Out:
# [0]
